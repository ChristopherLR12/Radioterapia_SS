# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib as mpl

def truncate(number: float, max_decimals: int) -> float:
    int_part, dec_part = str(number).split(".")
    return float(".".join((int_part, dec_part[:max_decimals])))

# %%
TB_15X = [[0.862,0.886,0.898,0.904,0.911,0.913,0.914,0.914],[0.888,0.919,0.936,0.950,0.958,0.963,0.967,0.968],[0.900,0.938,0.959,0.977,0.987,0.994,0.999,1.000],[0.911,0.954,0.979,1.000,1.016,1.024,1.031,1.033],[0.919,0.967,0.996,1.021,1.040,1.051,1.061,1.065],[0.923,0.973,1.004,1.032,1.053,1.066,1.079,1.083],[0.928,0.980,1.013,1.043,1.068,1.083,1.099,1.103],[0.931,0.984,1.017,1.048,1.075,1.091,1.108,1.113]]
VB_15X = [[0.856,0.88,0.891,0.899,0.904,0.908,0.91,0.911],[0.884,0.918,0.935,0.947,0.955,0.96,0.965,0.966],[0.897,0.938,0.958,0.973,0.985,0.991,0.997,0.999],[0.909,0.954,0.979,1,1.014,1.022,1.03,1.033],[0.917,0.968,0.996,1.02,1.039,1.051,1.062,1.065],[0.923,0.974,1.004,1.031,1.053,1.066,1.08,1.084],[0.927,0.981,1.013,1.042,1.068,1.084,1.101,1.107],[0.93,0.985,1.017,1.048,1.075,1.092,1.11,1.116]]
A_15X = [3,5,7,10,15,20,30,40]

TB_6FFF = [[0.845,0.870,0.883,0.892,0.898,0.901,0.904,0.905],[0.869,0.905,0.925,0.942,0.954,0.960,0.964,0.966],[0.884,0.925,0.951,0.973,0.990,0.997,1.003,1.005],[0.895,0.943,0.973,1.000,1.021,1.032,1.041,1.043],[0.904,0.957,0.991,1.024,1.050,1.064,1.076,1.081],[0.908,0.962,0.999,1.033,1.064,1.081,1.096,1.100],[0.912,0.969,1.007,1.045,1.079,1.098,1.116,1.122],[0.914,0.971,1.010,1.049,1.084,1.104,1.124,1.129]]
VB_6FFF = [[0.843,0.866,0.879,0.889,0.897,0.901,0.908,0.909],[0.868,0.903,0.922,0.939,0.951,0.958,0.968,0.969],[0.883,0.925,0.949,0.97,0.987,0.996,1.008,1.012],[0.895,0.943,0.973,1,1.021,1.033,1.048,1.053],[0.904,0.957,0.991,1.023,1.051,1.066,1.086,1.093],[0.908,0.964,1,1.034,1.067,1.084,1.107,1.115],[0.912,0.97,1.009,1.046,1.081,1.102,1.129,1.139],[0.914,0.973,1.012,1.051,1.088,1.109,1.137,1.147]]
A_6FFF = [3,5,7,10,15,20,30,40]

# %% [markdown]
# ## 15X

# %%
TB_15X
# Out:
# [[0.862, 0.886, 0.898, 0.904, 0.911, 0.913, 0.914, 0.914],
#  [0.888, 0.919, 0.936, 0.95, 0.958, 0.963, 0.967, 0.968],
#  [0.9, 0.938, 0.959, 0.977, 0.987, 0.994, 0.999, 1.0],
#  [0.911, 0.954, 0.979, 1.0, 1.016, 1.024, 1.031, 1.033],
#  [0.919, 0.967, 0.996, 1.021, 1.04, 1.051, 1.061, 1.065],
#  [0.923, 0.973, 1.004, 1.032, 1.053, 1.066, 1.079, 1.083],
#  [0.928, 0.98, 1.013, 1.043, 1.068, 1.083, 1.099, 1.103],
#  [0.931, 0.984, 1.017, 1.048, 1.075, 1.091, 1.108, 1.113]]

# %%
VB_15X
# Out:
# [[0.856, 0.88, 0.891, 0.899, 0.904, 0.908, 0.91, 0.911],
#  [0.884, 0.918, 0.935, 0.947, 0.955, 0.96, 0.965, 0.966],
#  [0.897, 0.938, 0.958, 0.973, 0.985, 0.991, 0.997, 0.999],
#  [0.909, 0.954, 0.979, 1, 1.014, 1.022, 1.03, 1.033],
#  [0.917, 0.968, 0.996, 1.02, 1.039, 1.051, 1.062, 1.065],
#  [0.923, 0.974, 1.004, 1.031, 1.053, 1.066, 1.08, 1.084],
#  [0.927, 0.981, 1.013, 1.042, 1.068, 1.084, 1.101, 1.107],
#  [0.93, 0.985, 1.017, 1.048, 1.075, 1.092, 1.11, 1.116]]

# %%
er_15X = np.zeros((len(A_15X),len(A_15X)))

for i in np.linspace(0,len(A_15X)-1,len(A_15X),dtype=int):
    for j in np.linspace(0,len(A_15X)-1,len(A_15X),dtype=int):
        er_15X[i][j] = truncate(((np.abs(TB_15X[i][j]-VB_15X[i][j]))/(TB_15X[i][j]))*100,3)
        
np.mean(er_15X)
# Out:
# 0.18485937500000002

# %%
tc = ["3","5","7","10","15","20","30","40"]

fig, ax = plt.subplots(figsize=(8,6))
im = ax.imshow(er_15X,cmap="Blues")


ax.set_xticks(np.arange(len(tc)), labels=tc, fontsize=13)
ax.set_yticks(np.arange(len(tc)), labels=tc, fontsize=13)

ax.spines[:].set_visible(False)

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

ax.set_title("Comparación 15X",size=16)
cb = fig.colorbar(im, ax=ax)
cb.set_label("Error relativo [%]", rotation=90,size=14)
plt.xlabel("x",size=14)
plt.ylabel("y",size=14)
fig.tight_layout()
plt.savefig("15X_hm1.pdf",bbox_inches="tight")

# %%
tc = ["3","5","7","10","15","20","30","40"]

fig, ax = plt.subplots(figsize=(8,6))
im = ax.imshow(er_15X,cmap="Blues")


ax.set_xticks(np.arange(len(tc)), labels=tc, fontsize=13)
ax.set_yticks(np.arange(len(tc)), labels=tc, fontsize=13)

ax.spines[:].set_visible(False)

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

for i in range(len(tc)):
    for j in range(len(tc)):
        text = ax.text(j, i, er_15X[i, j],
                       ha="center", va="center", color="k", fontsize=13, fontweight="book")

ax.set_title("Comparación 15X",size=16)
cb = fig.colorbar(im, ax=ax)
cb.set_label("Error relativo [%]", rotation=90,size=14)
plt.xlabel("x",size=14)
plt.ylabel("y",size=14)
fig.tight_layout()
plt.savefig("15X_hm2.pdf",bbox_inches="tight")

# %% [markdown]
# ## 6FFF

# %%
TB_6FFF
# Out:
# [[0.845, 0.87, 0.883, 0.892, 0.898, 0.901, 0.904, 0.905],
#  [0.869, 0.905, 0.925, 0.942, 0.954, 0.96, 0.964, 0.966],
#  [0.884, 0.925, 0.951, 0.973, 0.99, 0.997, 1.003, 1.005],
#  [0.895, 0.943, 0.973, 1.0, 1.021, 1.032, 1.041, 1.043],
#  [0.904, 0.957, 0.991, 1.024, 1.05, 1.064, 1.076, 1.081],
#  [0.908, 0.962, 0.999, 1.033, 1.064, 1.081, 1.096, 1.1],
#  [0.912, 0.969, 1.007, 1.045, 1.079, 1.098, 1.116, 1.122],
#  [0.914, 0.971, 1.01, 1.049, 1.084, 1.104, 1.124, 1.129]]

# %%
VB_6FFF
# Out:
# [[0.843, 0.866, 0.879, 0.889, 0.897, 0.901, 0.908, 0.909],
#  [0.868, 0.903, 0.922, 0.939, 0.951, 0.958, 0.968, 0.969],
#  [0.883, 0.925, 0.949, 0.97, 0.987, 0.996, 1.008, 1.012],
#  [0.895, 0.943, 0.973, 1, 1.021, 1.033, 1.048, 1.053],
#  [0.904, 0.957, 0.991, 1.023, 1.051, 1.066, 1.086, 1.093],
#  [0.908, 0.964, 1, 1.034, 1.067, 1.084, 1.107, 1.115],
#  [0.912, 0.97, 1.009, 1.046, 1.081, 1.102, 1.129, 1.139],
#  [0.914, 0.973, 1.012, 1.051, 1.088, 1.109, 1.137, 1.147]]

# %%
er_6FFF = np.zeros((len(A_6FFF),len(A_6FFF)))

for i in np.linspace(0,len(A_6FFF)-1,len(A_6FFF),dtype=int):
    for j in np.linspace(0,len(A_6FFF)-1,len(A_6FFF),dtype=int):
        er_6FFF[i][j] = truncate(((np.abs(TB_6FFF[i][j]-VB_6FFF[i][j]))/(TB_6FFF[i][j]))*100,3)

np.mean(er_6FFF)
# Out:
# 0.3466875

# %%
tc = ["3","5","7","10","15","20","30","40"]

fig, ax = plt.subplots(figsize=(8,6))
im = ax.imshow(er_6FFF,cmap="Blues")


ax.set_xticks(np.arange(len(tc)), labels=tc, fontsize=13)
ax.set_yticks(np.arange(len(tc)), labels=tc, fontsize=13)

ax.spines[:].set_visible(False)

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

ax.set_title("Comparación 6X FFF",size=16)
cb = fig.colorbar(im, ax=ax)
cb.set_label("Error relativo [%]", rotation=90,size=14)
plt.xlabel("x",size=14)
plt.ylabel("y",size=14)
fig.tight_layout()
plt.savefig("6FFF_hm1.pdf",bbox_inches="tight")

# %%
tc = ["3","5","7","10","15","20","30","40"]

fig, ax = plt.subplots(figsize=(8,6))
im = ax.imshow(er_6FFF,cmap="Blues")


ax.set_xticks(np.arange(len(tc)), labels=tc, fontsize=13)
ax.set_yticks(np.arange(len(tc)), labels=tc, fontsize=13)

ax.spines[:].set_visible(False)

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

for i in range(len(tc)):
    for j in range(len(tc)):
        text = ax.text(j, i, er_6FFF[i, j],
                       ha="center", va="center", color="k", fontsize=13, fontweight="book")

ax.set_title("Comparación 6X FFF VitalBeam respecto a TrueBeam",size=16)
cb = fig.colorbar(im, ax=ax)
cb.set_label("Error porcentual relativo [%]", rotation=90,size=14)
plt.xlabel("x",size=14)
plt.ylabel("y",size=14)
fig.tight_layout()
plt.savefig("6FFF_hm2.jpg",bbox_inches="tight",dpi=500)
