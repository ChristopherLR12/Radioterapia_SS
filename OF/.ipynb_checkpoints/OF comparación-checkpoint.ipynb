# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib as mpl

def truncate(number: float, max_decimals: int) -> float:
    int_part, dec_part = str(number).split(".")
    return float(".".join((int_part, dec_part[:max_decimals])))

# %%
TB_15X = [[0.862,0.877,0.904,0.913,0.914,0.914],[0.877,0.893,0.931,0.941,0.945,0.946],[0.911,0.935,1.000,1.024,1.031,1.033],[0.923,0.952,1.032,1.066,1.079,1.083],[0.928,0.957,1.043,1.083,1.099,1.103],[0.931,0.960,1.048,1.091,1.108,1.113]]
VB_15X = [[0.856,0.872,0.899,0.908,0.91,0.911],[0.874, 0.893,0.928, 0.938,0.943,0.943],[0.909,0.937,1,1.022,1.03,1.033],[0.923,0.953,1.031,1.066,1.08,1.084],[0.927,0.959,1.042,1.084,1.101,1.107],[0.93,0.962,1.048,1.092,1.11,1.116]]
A_15X = [3,4,10,20,30,40]

TB_6FFF = [[0.845,0.870,0.883,0.892,0.898,0.901,0.904,0.905],[0.869,0.905,0.925,0.942,0.954,0.960,0.964,0.966],[0.884,0.925,0.951,0.973,0.990,0.997,1.003,1.005],[0.895,0.943,0.973,1.000,1.021,1.032,1.041,1.043],[0.904,0.957,0.991,1.024,1.050,1.064,1.076,1.081],[0.908,0.962,0.999,1.033,1.064,1.081,1.096,1.100],[0.912,0.969,1.007,1.045,1.079,1.098,1.116,1.122],[0.914,0.971,1.010,1.049,1.084,1.104,1.124,1.129]]
VB_6FFF = [[0.843,0.866,0.879,0.889,0.897,0.901,0.908,0.909],[0.868,0.903,0.922,0.939,0.951,0.958,0.968,0.969],[0.883,0.925,0.949,0.97,0.987,0.996,1.008,1.012],[0.895,0.943,0.973,1,1.021,1.033,1.048,1.053],[0.904,0.957,0.991,1.023,1.051,1.066,1.086,1.093],[0.908,0.964,1,1.034,1.067,1.084,1.107,1.115],[0.912,0.97,1.009,1.046,1.081,1.102,1.129,1.139],[0.914,0.973,1.012,1.051,1.088,1.109,1.137,1.147]]
A_6FFF = [3,5,7,10,15,20,30,40]

# %% [markdown]
# ## 15X

# %%
er_15X = np.zeros((len(A_15X),len(A_15X)))

for i in np.linspace(0,len(A_15X)-1,len(A_15X),dtype=int):
    for j in np.linspace(0,len(A_15X)-1,len(A_15X),dtype=int):
        er_15X[i][j] = truncate(((np.abs(TB_15X[i][j]-VB_15X[i][j]))/(TB_15X[i][j]))*100,3)

# %%
tc = ["3","4","10","20","30","40"]

fig, ax = plt.subplots(figsize=(8,6))
im = ax.imshow(er_15X,cmap="Blues")


ax.set_xticks(np.arange(len(tc)), labels=tc, fontsize=13)
ax.set_yticks(np.arange(len(tc)), labels=tc, fontsize=13)

ax.spines[:].set_visible(False)

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

ax.set_title("Comparación 15X",size=16)
cb = fig.colorbar(im, ax=ax)
cb.set_label("Error relativo [%]", rotation=90,size=14)
plt.xlabel("x",size=14)
plt.ylabel("y",size=14)
fig.tight_layout()
plt.savefig("15X_hm1.pdf",bbox_inches="tight")

# %%
tc = ["3","4","10","20","30","40"]

fig, ax = plt.subplots(figsize=(8,6))
im = ax.imshow(er_15X,cmap="Blues")


ax.set_xticks(np.arange(len(tc)), labels=tc, fontsize=13)
ax.set_yticks(np.arange(len(tc)), labels=tc, fontsize=13)

ax.spines[:].set_visible(False)

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

for i in range(len(tc)):
    for j in range(len(tc)):
        text = ax.text(j, i, er_15X[i, j],
                       ha="center", va="center", color="k", fontsize=13, fontweight="book")

ax.set_title("Comparación 15X",size=16)
cb = fig.colorbar(im, ax=ax)
cb.set_label("Error relativo [%]", rotation=90,size=14)
plt.xlabel("x",size=14)
plt.ylabel("y",size=14)
fig.tight_layout()
plt.savefig("15X_hm2.pdf",bbox_inches="tight")

# %%
STB_15X = np.zeros(len(TB_15X))

for i in range(len(TB_15X)):
    STB_15X[i] = TB_15X[i][i]
    
SVB_15X = np.zeros(len(VB_15X))

for i in range(len(VB_15X)):
    SVB_15X[i] = VB_15X[i][i]

# %%
plt.figure(figsize=(8,6))
plt.plot(A_15X,STB_15X, c='navy', marker='o', markersize=10, label="OF TB",alpha=0.75)
plt.plot(A_15X,SVB_15X, c='red', marker="X", markersize=10, label="OF VB",alpha=0.75)
plt.title("Output Factor 15X",size=18)
plt.xlabel("Tamaño del campo cuadrado [cm]",size=14)
plt.ylabel("Output Factor",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("15X_s.pdf",bbox_inches="tight")

# %%
#3

p3 = truncate(np.mean(er_15X[0]),3)
pe_3 = np.ones(len(er_15X[0])) * p3


plt.figure(figsize=(8,6))
plt.scatter(A_15X,er_15X[0],s=80, c='navy', marker='o',label=r"Error relativo $\%$")
plt.plot(A_15X,pe_3,c="g",ls=":",lw="3",label="Promedio error = " + str(p3) + r"$\%$")
plt.title(r"$15X$ || $3 \times L$",size=18)
plt.xlabel(r"$L$",size=14)
plt.ylabel(r"Error relativo [$\%$]",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("15X_3.pdf",bbox_inches="tight")

# %%
#4

p4 = truncate(np.mean(er_15X[1]),3)
pe_4 = np.ones(len(er_15X[1])) * p4


plt.figure(figsize=(8,6))
plt.scatter(A_15X,er_15X[1],s=80, c='navy', marker='o',label=r"Error relativo $\%$")
plt.plot(A_15X,pe_4,c="g",ls=":",lw="3",label="Promedio error = " + str(p4) + r"$\%$")
plt.title(r"$15X$ || $4 \times L$",size=18)
plt.xlabel(r"$L$",size=14)
plt.ylabel(r"Error relativo [$\%$]",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("15X_4.pdf",bbox_inches="tight")

# %%
#10

p10 = truncate(np.mean(er_15X[2]),3)
pe_10 = np.ones(len(er_15X[2])) * p10


plt.figure(figsize=(8,6))
plt.scatter(A_15X,er_15X[2],s=80, c='navy', marker='o',label=r"Error relativo $\%$")
plt.plot(A_15X,pe_10,c="g",ls=":",lw="3",label="Promedio error = " + str(p10) + r"$\%$")
plt.title(r"$15X$ || $10 \times L$",size=18)
plt.xlabel(r"$L$",size=14)
plt.ylabel(r"Error relativo [$\%$]",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("15X_10.pdf",bbox_inches="tight")

# %%
#20

p20 = truncate(np.mean(er_15X[3]),3)
pe_20 = np.ones(len(er_15X[3])) * p20


plt.figure(figsize=(8,6))
plt.scatter(A_15X,er_15X[3],s=80, c='navy', marker='o',label=r"Error relativo $\%$")
plt.plot(A_15X,pe_20,c="g",ls=":",lw="3",label="Promedio error = " + str(p20) + r"$\%$")
plt.title(r"$15X$ || $20 \times L$",size=18)
plt.xlabel(r"$L$",size=14)
plt.ylabel(r"Error relativo [$\%$]",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("15X_20.pdf",bbox_inches="tight")

# %%
#30

p30 = truncate(np.mean(er_15X[4]),3)
pe_30 = np.ones(len(er_15X[4])) * p30


plt.figure(figsize=(8,6))
plt.scatter(A_15X,er_15X[4],s=80, c='navy', marker='o',label=r"Error relativo $\%$")
plt.plot(A_15X,pe_30,c="g",ls=":",lw="3",label="Promedio error = " + str(p30) + r"$\%$")
plt.title(r"$15X$ || $30 \times L$",size=18)
plt.xlabel(r"$L$",size=14)
plt.ylabel(r"Error relativo [$\%$]",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("15X_30.pdf",bbox_inches="tight")

# %%
#40

p40 = truncate(np.mean(er_15X[5]),3)
pe_40 = np.ones(len(er_15X[5])) * p40


plt.figure(figsize=(8,6))
plt.scatter(A_15X,er_15X[5],s=80, c='navy', marker='o',label=r"Error relativo $\%$")
plt.plot(A_15X,pe_40,c="g",ls=":",lw="3",label="Promedio error = " + str(p40) + r"$\%$")
plt.title(r"$15X$ || $40 \times L$",size=18)
plt.xlabel(r"$L$",size=14)
plt.ylabel(r"Error relativo [$\%$]",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("15X_40.pdf",bbox_inches="tight")

# %% [markdown]
# ## 6FFF

# %%
er_6FFF = np.zeros((len(A_6FFF),len(A_6FFF)))

for i in np.linspace(0,len(A_6FFF)-1,len(A_6FFF),dtype=int):
    for j in np.linspace(0,len(A_6FFF)-1,len(A_6FFF),dtype=int):
        er_6FFF[i][j] = truncate(((np.abs(TB_6FFF[i][j]-VB_6FFF[i][j]))/(TB_6FFF[i][j]))*100,3)

# %%
tc = ["3","5","7","10","15","20","30","40"]

fig, ax = plt.subplots(figsize=(8,6))
im = ax.imshow(er_6FFF,cmap="Blues")


ax.set_xticks(np.arange(len(tc)), labels=tc, fontsize=13)
ax.set_yticks(np.arange(len(tc)), labels=tc, fontsize=13)

ax.spines[:].set_visible(False)

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

ax.set_title("Comparación 6X FFF",size=16)
cb = fig.colorbar(im, ax=ax)
cb.set_label("Error relativo [%]", rotation=90,size=14)
plt.xlabel("x",size=14)
plt.ylabel("y",size=14)
fig.tight_layout()
plt.savefig("6FFF_hm1.pdf",bbox_inches="tight")

# %%
tc = ["3","5","7","10","15","20","30","40"]

fig, ax = plt.subplots(figsize=(8,6))
im = ax.imshow(er_6FFF,cmap="Blues")


ax.set_xticks(np.arange(len(tc)), labels=tc, fontsize=13)
ax.set_yticks(np.arange(len(tc)), labels=tc, fontsize=13)

ax.spines[:].set_visible(False)

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

for i in range(len(tc)):
    for j in range(len(tc)):
        text = ax.text(j, i, er_6FFF[i, j],
                       ha="center", va="center", color="k", fontsize=13, fontweight="book")

ax.set_title("Comparación 6X FFF",size=16)
cb = fig.colorbar(im, ax=ax)
cb.set_label("Error relativo [%]", rotation=90,size=14)
plt.xlabel("x",size=14)
plt.ylabel("y",size=14)
fig.tight_layout()
plt.savefig("6FFF_hm2.pdf",bbox_inches="tight")

# %%
STB_6FFF = np.zeros(len(TB_6FFF))

for i in range(len(TB_6FFF)):
    STB_6FFF[i] = TB_6FFF[i][i]
    
SVB_6FFF = np.zeros(len(VB_6FFF))

for i in range(len(VB_6FFF)):
    SVB_6FFF[i] = VB_6FFF[i][i]

# %%
plt.figure(figsize=(8,6))
plt.plot(A_6FFF,STB_6FFF, c='navy', marker='o', markersize=10, label="OF TB",alpha=0.75)
plt.plot(A_6FFF,SVB_6FFF, c='red', marker="X", markersize=10, label="OF VB",alpha=0.75)
plt.title("Output Factor 6X FFF",size=18)
plt.xlabel("Tamaño del campo cuadrado [cm]",size=14)
plt.ylabel("Output Factor",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("6FFF_s.pdf",bbox_inches="tight")

# %%
#3

p3 = truncate(np.mean(er_6FFF[0]),3)
pe_3 = np.ones(len(er_6FFF[0])) * p3


plt.figure(figsize=(8,6))
plt.scatter(A_6FFF,er_6FFF[0],s=80, c='navy', marker='o',label=r"Error relativo $\%$")
plt.plot(A_6FFF,pe_3,c="g",ls=":",lw="3",label="Promedio error = " + str(p3) + r"$\%$")
plt.title(r"$6X$ $FFF$ || $3 \times L$",size=18)
plt.xlabel(r"$L$",size=14)
plt.ylabel(r"Error relativo [$\%$]",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("6FFF_3.pdf",bbox_inches="tight")

# %%
#5

p5 = truncate(np.mean(er_6FFF[1]),3)
pe_5 = np.ones(len(er_6FFF[1])) * p5


plt.figure(figsize=(8,6))
plt.scatter(A_6FFF,er_6FFF[1],s=80, c='navy', marker='o',label=r"Error relativo $\%$")
plt.plot(A_6FFF,pe_5,c="g",ls=":",lw="3",label="Promedio error = " + str(p5) + r"$\%$")
plt.title(r"$6X$ $FFF$ || $5 \times L$",size=18)
plt.xlabel(r"$L$",size=14)
plt.ylabel(r"Error relativo [$\%$]",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("6FFF_5.pdf",bbox_inches="tight")

# %%
#7

p7 = truncate(np.mean(er_6FFF[2]),3)
pe_7 = np.ones(len(er_6FFF[2])) * p7


plt.figure(figsize=(8,6))
plt.scatter(A_6FFF,er_6FFF[2],s=80, c='navy', marker='o',label=r"Error relativo $\%$")
plt.plot(A_6FFF,pe_7,c="g",ls=":",lw="3",label="Promedio error = " + str(p7) + r"$\%$")
plt.title(r"$6X$ $FFF$ || $7 \times L$",size=18)
plt.xlabel(r"$L$",size=14)
plt.ylabel(r"Error relativo [$\%$]",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("6FFF_7.pdf",bbox_inches="tight")

# %%
#10

p10 = truncate(np.mean(er_6FFF[3]),3)
pe_10 = np.ones(len(er_6FFF[3])) * p10


plt.figure(figsize=(8,6))
plt.scatter(A_6FFF,er_6FFF[3],s=80, c='navy', marker='o',label=r"Error relativo $\%$")
plt.plot(A_6FFF,pe_10,c="g",ls=":",lw="3",label="Promedio error = " + str(p10) + r"$\%$")
plt.title(r"$6X$ $FFF$ || $10 \times L$",size=18)
plt.xlabel(r"$L$",size=14)
plt.ylabel(r"Error relativo [$\%$]",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("6FFF_10.pdf",bbox_inches="tight")

# %%
#15

p15 = truncate(np.mean(er_6FFF[4]),3)
pe_15 = np.ones(len(er_6FFF[4])) * p15


plt.figure(figsize=(8,6))
plt.scatter(A_6FFF,er_6FFF[4],s=80, c='navy', marker='o',label=r"Error relativo $\%$")
plt.plot(A_6FFF,pe_15,c="g",ls=":",lw="3",label="Promedio error = " + str(p15) + r"$\%$")
plt.title(r"$6X$ $FFF$ || $20 \times L$",size=18)
plt.xlabel(r"$L$",size=14)
plt.ylabel(r"Error relativo [$\%$]",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("6FFF_20.pdf",bbox_inches="tight")

# %%
#20

p20 = truncate(np.mean(er_6FFF[5]),3)
pe_20 = np.ones(len(er_6FFF[5])) * p20


plt.figure(figsize=(8,6))
plt.scatter(A_6FFF,er_6FFF[5],s=80, c='navy', marker='o',label=r"Error relativo $\%$")
plt.plot(A_6FFF,pe_20,c="g",ls=":",lw="3",label="Promedio error = " + str(p20) + r"$\%$")
plt.title(r"$6X$ $FFF$ || $20 \times L$",size=18)
plt.xlabel(r"$L$",size=14)
plt.ylabel(r"Error relativo [$\%$]",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("6FFF_20.pdf",bbox_inches="tight")

# %%
#30

p30 = truncate(np.mean(er_6FFF[6]),3)
pe_30 = np.ones(len(er_6FFF[6])) * p30


plt.figure(figsize=(8,6))
plt.scatter(A_6FFF,er_6FFF[6],s=80, c='navy', marker='o',label=r"Error relativo $\%$")
plt.plot(A_6FFF,pe_30,c="g",ls=":",lw="3",label="Promedio error = " + str(p30) + r"$\%$")
plt.title(r"$6X$ $FFF$ || $30 \times L$",size=18)
plt.xlabel(r"$L$",size=14)
plt.ylabel(r"Error relativo [$\%$]",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("6FFF_30.pdf",bbox_inches="tight")

# %%
#40

p40 = truncate(np.mean(er_6FFF[7]),3)
pe_40 = np.ones(len(er_6FFF[7])) * p40


plt.figure(figsize=(8,6))
plt.scatter(A_6FFF,er_6FFF[7],s=80, c='navy', marker='o',label=r"Error relativo $\%$")
plt.plot(A_6FFF,pe_40,c="g",ls=":",lw="3",label="Promedio error = " + str(p40) + r"$\%$")
plt.title(r"$6X$ $FFF$ || $40 \times L$",size=18)
plt.xlabel(r"$L$",size=14)
plt.ylabel(r"Error relativo [$\%$]",size=14)
plt.legend(fontsize=14)
plt.grid(color='k',alpha=0.4)
plt.savefig("6FFF_40.pdf",bbox_inches="tight")
