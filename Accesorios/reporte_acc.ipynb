# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\c-lop\Documents\GitHub\Radioterapia_SS\Accesorios\colocacion_pre_radiocirugia.csv")

# %%
data.describe()
# Out:
#        numero_de_realizacion  soporte_moldeable  uso_soporte_moldeable  \
# count              18.000000               18.0              18.000000
# mean                9.500000                1.0               5.166667
# std                 5.338539                0.0               2.915476
# min                 1.000000                1.0               1.000000
# 25%                 5.250000                1.0               3.000000
# 50%                 9.500000                1.0               5.000000
# 75%                13.750000                1.0               7.000000
# max                18.000000                1.0              10.000000
#
#          mascara  uso_mascara  mordedera  uso_mordedera  tiempo_realizacion  \
# count  18.000000    11.000000  18.000000        5.00000           18.000000
# mean    0.611111     3.000000   0.277778        2.20000           35.555556
# std     0.501631     1.788854   0.460889        1.30384            8.204893
# ...
